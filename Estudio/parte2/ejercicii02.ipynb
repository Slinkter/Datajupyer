# %%
import pandas as pd

# %%
df_laptop = pd.read_csv("./laptop_price.csv" , encoding="latin-1")

# %%
df_laptop.head(3)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                            1440x900        Intel Core i5 1.8GHz  8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00

# %%
df1 = df_laptop["Company"].isin(["Apple","HP"])

# %%
df1
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301     True
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
df_laptop[df1]
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# 2             3      HP                               250 G6   Notebook
# 3             4   Apple                          MacBook Pro  Ultrabook
# 4             5   Apple                          MacBook Pro  Ultrabook
# ...         ...     ...                                  ...        ...
# 1282       1300      HP                     Stream 11-Y000na    Netbook
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1294       1312      HP                  Pavilion 15-AW003nv   Notebook
# 1296       1314      HP                     Stream 11-Y000na    Netbook
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
#       Inches                    ScreenResolution  \
# 0       13.3  IPS Panel Retina Display 2560x1600
# ...

# %%
df_laptop[df1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295 entries, 0 to 1301
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         295 non-null    int64
#  1   Company           295 non-null    object
#  2   Product           295 non-null    object
#  3   TypeName          295 non-null    object
#  4   Inches            295 non-null    float64
#  5   ScreenResolution  295 non-null    object
#  6   Cpu               295 non-null    object
#  7   Ram               295 non-null    object
#  8   Memory            295 non-null    object
#  9   Gpu               295 non-null    object
#  10  OpSys             295 non-null    object
#  11  Weight            295 non-null    object
#  12  Price_euros       295 non-null    float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 32.3+ KB

# %%
df_laptop[df1].describe()
# Out:
#          laptop_ID      Inches  Price_euros
# count   295.000000  295.000000   295.000000
# mean    675.277966   14.822373  1103.113492
# std     412.416519    1.499855   626.008031
# min       1.000000   11.600000   209.000000
# 25%     286.000000   13.300000   639.450000
# 50%     729.000000   15.600000  1000.000000
# 75%    1043.500000   15.600000  1409.000000
# max    1319.000000   17.300000  4389.000000

# %%
filter1 = df_laptop["Company"].isin(["Apple","HP"])
filter2 = df_laptop["TypeName"].isin(["Notebook","Ultrabook"])

# %%
df_laptop[filter1 & filter2]
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# 2             3      HP                               250 G6   Notebook
# 3             4   Apple                          MacBook Pro  Ultrabook
# 4             5   Apple                          MacBook Pro  Ultrabook
# ...         ...     ...                                  ...        ...
# 1273       1291      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1280       1298      HP                  Pavilion 15-AW003nv   Notebook
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1294       1312      HP                  Pavilion 15-AW003nv   Notebook
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
#       Inches                    ScreenResolution                         Cpu  \
# ...

# %%
df_laptop[filter1 & filter2].describe()
# Out:
#          laptop_ID      Inches  Price_euros
# count   241.000000  241.000000   241.000000
# mean    649.095436   14.870124   989.396432
# std     425.732344    1.345122   517.668671
# min       1.000000   11.600000   229.000000
# 25%     234.000000   14.000000   598.990000
# 50%     671.000000   15.600000   914.000000
# 75%    1043.000000   15.600000  1244.000000
# max    1319.000000   17.300000  3100.000000

# %%
df_laptop.head(3)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                            1440x900        Intel Core i5 1.8GHz  8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00

# %%
filter_Duplicado= df_laptop.duplicated("laptop_ID")

# %%
df_laptop[filter_Duplicado]
# Out:
# Empty DataFrame
# Columns: [laptop_ID, Company, Product, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price_euros]
# Index: []

# %%
duplicado01 = df_laptop.duplicated(["Product","TypeName","Inches"])

# %%
duplicado01
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1298     True
# 1299     True
# 1300     True
# 1301     True
# 1302     True
# Length: 1303, dtype: bool

# %%
df_laptop[duplicado01].sort_values(["Product","TypeName"])
# Out:
#       laptop_ID Company                              Product  \
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1098       1113      HP                               250 G5
# 1170       1188      HP                               250 G5
# 10           11      HP                               250 G6
# ...         ...     ...                                  ...
# 414         421    Asus                         ZenBook Flip
# 826         835    Asus                         ZenBook Flip
# 1275       1293    Asus                 ZenBook UX305CA-UBM1
# 1289       1307    Asus                 ZenBook UX305CA-UBM1
# 676         684    Asus                            Zenbook 3
#
#                 TypeName  Inches                           ScreenResolution  \
# 1287            Notebook    15.6                                   1366x768
# 1301            Notebook    15.6                                   1366x768
# ...

# %%
df_laptop_filter = df_laptop.sort_values(["Company","Price_euros"])

# %%
df_laptop_filter.head(50)
# Out:
#       laptop_ID Company                                   Product  \
# 1215       1233    Acer          C740-C9QX (3205U/2GB/32GB/Chrome
# 290         295    Acer                      Chromebook C910-C2ST
# 1102       1117    Acer                             Chromebook 15
# 695         703    Acer                         TravelMate B117-M
# 1198       1216    Acer                                  Aspire 3
# 1263       1281    Acer                            Aspire ES1-531
# 1277       1295    Acer                            Aspire ES1-531
# 1291       1309    Acer                            Aspire ES1-531
# 888         899    Acer                      Chromebook C731-C78G
# 769         778    Acer                            Aspire A315-31
# 602         609    Acer                                  Aspire 1
# 745         753    Acer                             Chromebook 14
# 1183       1201    Acer                                  Aspire 3
# ...

# %%
import pandas as pd
df2_laptops = pd.read_csv("./laptop_price.csv", encoding="latin-1")

# %%
df2_laptops.drop_duplicates(["Company"])
# Out:
#      laptop_ID    Company                        Product            TypeName  \
# 0            1      Apple                    MacBook Pro           Ultrabook
# 2            3         HP                         250 G6            Notebook
# 5            6       Acer                       Aspire 3            Notebook
# 8            9       Asus                ZenBook UX430UN           Ultrabook
# 13          14       Dell                  Inspiron 3567            Notebook
# 18          19     Lenovo              IdeaPad 320-15IKB            Notebook
# 30          31      Chuwi                  LapBook 15.6"            Notebook
# 58          59        MSI                     GS73VR 7RG              Gaming
# 70          72  Microsoft                 Surface Laptop           Ultrabook
# 143        146    Toshiba                  Satellite Pro            Notebook
# 170        174     Huawei                     MateBook X           Ultrabook
# ...

# %%
df2_laptops.drop_duplicates(["Company"])
# Out:
#      laptop_ID    Company                        Product            TypeName  \
# 0            1      Apple                    MacBook Pro           Ultrabook
# 2            3         HP                         250 G6            Notebook
# 5            6       Acer                       Aspire 3            Notebook
# 8            9       Asus                ZenBook UX430UN           Ultrabook
# 13          14       Dell                  Inspiron 3567            Notebook
# 18          19     Lenovo              IdeaPad 320-15IKB            Notebook
# 30          31      Chuwi                  LapBook 15.6"            Notebook
# 58          59        MSI                     GS73VR 7RG              Gaming
# 70          72  Microsoft                 Surface Laptop           Ultrabook
# 143        146    Toshiba                  Satellite Pro            Notebook
# 170        174     Huawei                     MateBook X           Ultrabook
# ...

# %%
df2_laptops.drop_duplicates(["Company"])[["Company","Price_euros"]].sort_values("Price_euros")
# Out:
#        Company  Price_euros
# 30       Chuwi       244.99
# 191       Vero       260.00
# 430    Samsung       269.00
# 429   Mediacom       299.00
# 5         Acer       400.00
# 13        Dell       498.90
# 18      Lenovo       499.00
# 2           HP       575.00
# 143    Toshiba       602.00
# 567    Fujitsu       739.00
# 70   Microsoft      1089.00
# 184     Xiaomi      1199.00
# 0        Apple      1339.69
# 170     Huawei      1349.00
# 8         Asus      1495.00
# 437     Google      2199.00
# 678         LG      2299.00
# 58         MSI      2449.00
# 196      Razer      6099.00

# %%
df_laptop["Inches"].unique()
# Out:
# array([13.3, 15.6, 15.4, 14. , 12. , 11.6, 17.3, 10.1, 13.5, 12.5, 13. ,
#        18.4, 13.9, 12.3, 17. , 15. , 14.1, 11.3])

# %%
len(df_laptop["Company"].unique())
# Out:
# 19
