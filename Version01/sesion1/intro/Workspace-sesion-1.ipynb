# %%
12312

# %%
ñ_ñ = 11

# %%
print(ñ_ñ)

# %%
()

# %%
(1, 2, 3)

# %%
tuple((1, 2, 3))

# %%
None

# %%
print(r"Startup studio\n")

# %%
print("Startup studio \n")

# %%
colleccion = ([], [])

# %%
colleccion[0].append(1)

# %%
colleccion

# %%
nombre = 'Joel Rivera'

# %%
nums = list(range(10))

# %%
nums

# %%
nums[0:5]

# %%
nums[5]

# %%
import string

# %%
letters = list(string.ascii_letters)

# %%
letters

# %%
len(letters)

# %%
letters[:5]

# %%
letters[0: -2]

# %%
letters[-1:0:-1]

# %%
nombre = {}

# %%
t = (1, 0)

# %%
tupla_en_dict = {t: "Joel"}

# %%
tupla_en_dict[(1, 0)]

# %%
tupla_en_dict['nombre'] = "Joel"

# %%
tupla_en_dict

# %%
tupla_en_dict[('a', 'b', 'c')] = 1

# %%
t == (1, 0)

# %%
t is (1, 0)

# %%
hash((1, 0))

# %%
hash(t)

# %%
tupla_en_dict

# %%
None is tupla_en_dict.get('nomb')

# %%
tupla_en_dict.keys()

# %%
tupla_en_dict.values()

# %%
tupla_en_dict.g

# %%
11 / 2

# %%
divmod(11, 2)

# %%
import decimal

# %%
11 * 2

# %%
'11' + '22'

# %%
frutas = {'manzana': 1, 'pera': 2, 'fresa': 10, 'uva': 100}

for fruta, id_fruta in frutas.items():
    print(fruta, id_fruta)

# %%
tuple(frutas.items())

# %%
del frutas['uva']

# %%
frutas

# %%
import collections

# %%
d = collections.OrderedDict()

# %%
d['nombre'] = 'Joel'

# %%
d['edad'] = 28

# %%
for k in d:
    print(k)

# %%
# !tree mipaquete
# Out:
# mipaquete
# ├── __init__.py
# └── saludos.py
#
# 1 directory, 2 files

# %%
from mipaquete import saludos

# %%
saludos.hola()
# Out:
# Hola alumnos

# %%
# !tree nssample/
# Out:
# nssample/
# ├── part1
# │   └── frutas
# │       └── manzanas.py
# ├── part2
# │   └── frutas
# │       └── naranjas.py
# └── part3
#     └── frutas
#         └── uvas.py
#
# 7 directories, 3 files

# %%
import sys

# %%
sys.path.append("nssample/part1")
sys.path.append("nssample/part2")

# %%
import frutas.manzanas

# %%
frutas.manzanas
# Out:
# <module 'frutas.manzanas' from '/Users/ljcr/Documents/GitHub/Datajupyer/Version01/sesion1/intro/nssample/part1/frutas/manzanas.py'>

# %%
print(frutas.manzanas.get())
# Out:
# Manzanas

# %%
import frutas.naranjas
print(frutas.naranjas.get())
# Out:
# Naranjas!

# %%
sys.path.append("nssample/part3")
from frutas import uvas
print(uvas.get())
# Out:
# Uvas!
