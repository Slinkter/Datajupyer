# %%
import sys
print(sys.base_prefix)   # Ruta del Python base
print(sys.prefix)        # Ruta del entorno actual
print(sys.prefix != sys.base_prefix)  # True si estás en un venv
# Out:
# /Users/ljcr/anaconda3/envs/ds_env
# /Users/ljcr/anaconda3/envs/ds_env
# False

# %%
print("hola")
# Out:
# hola

# %%
import numpy as np

# %%
x = [0,1,2,3,4]
print(x)
# Out:
# [0, 1, 2, 3, 4]

# %%
y = np.array(x)
print(y)
print(type(y))
print(y*y)
print(y.size)
print(y.dtype)

# %%
np.identity(n=5)

# %%
np.ones(shape=[5,5])

# %%
np.zeros(shape=[5,5])

# %%
y = [0, 1, 2, 3, 4]
# y * y

# %%
np.ndim(y)

# %%
x = np.array([[1,2,3,4],[21,22,23,24],[31,32,33,34],[41,42,43,44],[51,52,53,54]])
np.ndim(x)

# %%
print(x)
print(x.shape)

# %%
x.flatten()

# %%
x
x.dtype

# %%
x.T

# %%
x + 100

# %%
x * 2

# %%
x ** 2

# %%
x + x

# %%
x * x

# %%
print(np.mean(x))
print(x.mean())

# %%
np.mean(x,axis=0)

# %%
import pandas as pd
import os
print(os.getcwd())

# %%
# pd por convención
nuevo_campos = ['id_poliza', 'codigo_estado', 'condado', 'limite_terremoto',
    'limite_huracan', 'limite_inundacion', 'limite_incendio',
    'valor_asegurado_2011', 'valor_asegurado_2012',
    'deducible_terremoto', 'deducible_huracan', 'deducible_inundacion', 'deducible_incendio',
    'latitud', 'longitud', 'tipo_propiedad', 'material_construccion', 'granularidad']


# Opción 1: Cambiar al directorio correcto
os.chdir(r'C:\Users\LJCR\Documents\GitHub\Datajupyer\Version01\sesion2\2.- Scientific Python Stack y Big Data Engineering')
data = pd.read_csv('FL_insurance_sample.csv',names=nuevo_campos,header=0)

# %%
data

# %%
print(data.info)

# %%
print(data.describe)

# %%
type(data)

# %%
s=pd.Series([0.10,1.20,2.23,3.4,4.5])
print(s)

# %%
s1=pd.Series([0.10,1.20,2.23,3.4,4.5],index=["a","b","c","d","e"])

# %%
s1

# %%
s1[['a','c']]

# %%
s1[s1>2]

# %%
data = pd.read_csv('./train.csv')
print(type(data))
print('- - '*10)
print(data.dtypes)

# %%
data

# %%
nuevos_nombres = {
    'PassengerId': 'id_pasajero',
    'Survived': 'sobrevivio',
    'Pclass': 'clase',
    'Name': 'nombre',
    'Sex': 'genero',
    'Age': 'edad',
    'SibSp': 'hermanos_conyuge',
    'Parch': 'padres_hijos',
    'Ticket': 'ticket',
    'Fare': 'tarifa',
    'Cabin': 'cabina',
    'Embarked': 'embarque'
}

data.rename(columns= nuevo_campos,inplace=true)



data.describe()
