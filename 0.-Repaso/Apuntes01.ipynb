# %%
conda install pandas numpy matplotlib seaborn scikit-learn
# Out:
# Channels:
#  - defaults
# Platform: osx-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/py-312
#
#   added / updated specs:
#     - matplotlib
#     - numpy
#     - pandas
#     - scikit-learn
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-python-1.0.9        |  py312h6d0c2b6_9         384 KB
#     cairo-1.16.0               |       h08824b9_6         1.0 MB
#     contourpy-1.3.1            |  py312h1962661_0         270 KB
#     fontconfig-2.14.1          |       h269ac6a_3         249 KB
#     fonttools-4.55.3           |  py312h46256e1_0         2.9 MB
#     freetype-2.13.3            |       h02243ff_0         648 KB
#     fribidi-1.0.10             |       haf1e3a3_0          63 KB
#     graphite2-1.3.14           |       he9d5cce_1          82 KB
# ...

# %%
import pandas as pd
import numpy as np
