# %%
# !python --version
# Out:
# Python 3.14.7

# %%
lista1=[]
lista2=[12,12.02,"III",12+4j,True]
lista3=[2,45,56,23,98,0,12]

# %%
print(type(lista1))
print(type(lista2))
print(type(lista3))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
lista2[:3]
# Out:
# [12, 12.02, 'III']

# %%
lista3[-3:]
# Out:
# [98, 0, 12]

# %%
lista4=lista2+lista3
lista4
# Out:
# [12, 12.02, 'III', (12+4j), True, 2, 45, 56, 23, 98, 0, 12]

# %%
lista5 = lista4*5
lista5
# Out:
# [12,
#  12.02,
#  'III',
#  (12+4j),
#  True,
#  2,
#  45,
#  56,
#  23,
#  98,
#  0,
#  12,
#  12,
#  12.02,
#  'III',
#  (12+4j),
#  True,
#  2,
#  45,
#  56,
#  23,
#  98,
#  0,
#  12,
#  12,
#  12.02,
#  'III',
#  (12+4j),
#  True,
#  2,
#  45,
#  56,
#  23,
#  98,
#  0,
#  12,
#  12,
#  12.02,
#  'III',
#  (12+4j),
#  True,
#  2,
#  45,
#  56,
#  23,
#  98,
#  0,
#  12,
#  12,
#  12.02,
#  'III',
#  (12+4j),
#  True,
#  2,
#  45,
#  56,
#  23,
#  98,
#  0,
#  12]

# %%
lista_listas = [lista1, lista2, lista3, lista4, lista5]
print(lista_listas)
print(len(lista_listas))
# Out:
# [[], [12, 12.02, 'III', (12+4j), True], [2, 45, 56, 23, 98, 0, 12], [12, 12.02, 'III', (12+4j), True, 2, 45, 56, 23, 98, 0, 12], [12, 12.02, 'III', (12+4j), True, 2, 45, 56, 23, 98, 0, 12, 12, 12.02, 'III', (12+4j), True, 2, 45, 56, 23, 98, 0, 12, 12, 12.02, 'III', (12+4j), True, 2, 45, 56, 23, 98, 0, 12, 12, 12.02, 'III', (12+4j), True, 2, 45, 56, 23, 98, 0, 12, 12, 12.02, 'III', (12+4j), True, 2, 45, 56, 23, 98, 0, 12]]
# 5

# %%
for temp in lista_listas:
    print(type(temp))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
import random as rnd 
datos = []
for elemento in range(10):
    datos = datos + [rnd.randint(0,20)]
datos
# Out:
# [14, 10, 16, 7, 20, 5, 7, 3, 3, 16]

# %%
len(datos)
# Out:
# 10

# %%
sum(datos)/len(datos)
# Out:
# 10.1

# %%
aprobados = []
for temp in datos:
    if temp>=14:
        aprobados = aprobados +[temp]

aprobados
# Out:
# [14, 16, 20, 16]

# %%
dir(lista1)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
lista = [1,2,3,4,]
lista.append(5)
print(lista)
# Out:
# [1, 2, 3, 4, 5]

# %%
lista = [1,2,3,4,]
lista.clear()
print(lista)
# Out:
# []

# %%
lista = [1,2,3]
lista_copy= lista.copy()
print(lista_copy)
# Out:
# [1, 2, 3]

# %%
lista = [1, 2, 2, 3, 2]
print(lista.count(2))
# Out:
# 3
