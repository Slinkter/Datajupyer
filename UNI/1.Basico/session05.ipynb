# %%
# !python --version
# Out:
# Python 3.13.5

# %%
lista1=[]
lista2=[12,12.02,"III",12+4j,True]
lista3=[2,45,56,23,98,0,12]

# %%
print(type(lista1))
print(type(lista2))
print(type(lista3))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
lista2[:3]
# Out:
# [12, 12.02, 'III']

# %%
lista3[-3:]
# Out:
# [98, 0, 12]

# %%
lista4=lista2+lista3
lista4
# Out:
# [12, 12.02, 'III', (12+4j), True, 2, 45, 56, 23, 98, 0, 12]

# %%
lista5 = lista4*5
lista5
# Out:
# [12,
#  12.02,
#  'III',
#  (12+4j),
#  True,
#  2,
#  45,
#  56,
#  23,
#  98,
#  0,
#  12,
#  12,
#  12.02,
#  'III',
#  (12+4j),
#  True,
#  2,
#  45,
#  56,
#  23,
#  98,
#  0,
#  12,
#  12,
#  12.02,
#  'III',
#  (12+4j),
#  True,
#  2,
#  45,
#  56,
#  23,
#  98,
#  0,
#  12,
#  12,
#  12.02,
#  'III',
#  (12+4j),
#  True,
#  2,
#  45,
#  56,
#  23,
#  98,
#  0,
#  12,
#  12,
#  12.02,
#  'III',
#  (12+4j),
#  True,
#  2,
#  45,
#  56,
#  23,
#  98,
#  0,
#  12]

# %%
lista_listas = [lista1, lista2, lista3, lista4, lista5]
print(lista_listas)
print(len(lista_listas))
# Out:
# [[], [12, 12.02, 'III', (12+4j), True], [2, 45, 56, 23, 98, 0, 12], [12, 12.02, 'III', (12+4j), True, 2, 45, 56, 23, 98, 0, 12], [12, 12.02, 'III', (12+4j), True, 2, 45, 56, 23, 98, 0, 12, 12, 12.02, 'III', (12+4j), True, 2, 45, 56, 23, 98, 0, 12, 12, 12.02, 'III', (12+4j), True, 2, 45, 56, 23, 98, 0, 12, 12, 12.02, 'III', (12+4j), True, 2, 45, 56, 23, 98, 0, 12, 12, 12.02, 'III', (12+4j), True, 2, 45, 56, 23, 98, 0, 12]]
# 5

# %%
for temp in lista_listas:
    print(type(temp))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
import random as rnd 
datos = []
for elemento in range(10):
    datos = datos + [rnd.randint(0,20)]
datos
# Out:
# [14, 10, 16, 7, 20, 5, 7, 3, 3, 16]

# %%
len(datos)
# Out:
# 10

# %%
sum(datos)/len(datos)
# Out:
# 10.1

# %%
aprobados = []
for temp in datos:
    if temp>=14:
        aprobados = aprobados +[temp]

aprobados
# Out:
# [14, 16, 20, 16]

# %%
dir(lista1)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
lista = [1,2,3,4,]
lista.append(5)
print(lista)
# Out:
# [1, 2, 3, 4, 5]

# %%
lista = [1,2,3,4,]
lista.clear()
print(lista)
# Out:
# []

# %%
lista = [1,2,3]
lista_copy= lista.copy()
print(lista_copy)
# Out:
# [1, 2, 3]

# %%
lista = [1, 2, 2, 3, 2]
print(lista.count(2))
# Out:
# 3

# %%
import random as rnd 

datos = []
for x in range(10):
    datos = datos+ [rnd.randint(11,19)]

print(datos)
# Out:
# [17, 11, 19, 14, 19, 13, 19, 15, 13, 19]

# %%
import random as rnd
datos = []
for x in range(0,20):
    datos = datos +[rnd.randint(11,20)]
print(datos)
print(len(datos))
# Out:
# [15, 15, 16, 20, 19, 16, 17, 20, 20, 13, 18, 12, 17, 14, 12, 20, 16, 17, 18, 13]
# 20

# %%
help([].append)
# Out:
# Help on built-in function append:
#
# append(object, /) method of builtins.list instance
#     Append object to the end of the list.

# %%
import random as rnd
datos = []
for x in range(0,20):
    datos.append(rnd.randint(11,20))

print(datos)
# Out:
# [19, 15, 19, 18, 12, 14, 12, 17, 15, 19, 16, 14, 20, 20, 18, 12, 12, 20, 19, 12]

# %%
listacurso = []
listacurso.append('luis','ana')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 listacurso = []
# ----> 2 listacurso.append('luis','ana')
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
#crear tamano de la lista
# ingresa datos de la lista

listaN = []
n = int(input('ingresar en tamanio de la lista'))
i =0
while  i < n:
    dato = int(input('ingresa tu dato  rango[1-6]'))
    if (dato<=0 and dato>=7):
        print('fuera de rango')
        continue
    listaN.append(dato)
    i=i+1


print(listaN)
listaN.clear()
print(listaN)
del listaN
print(listaN)
# Out:
# [1, 2, 3]
# []
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 20
#      16 print(listaN)
#      17 listaN.clear()
#      18 print(listaN)
#      19 del listaN
# ---> 20 print(listaN)
#
# NameError: name 'listaN' is not defined

# %%
lista8 = []
lista8.extend("ARRIBA PERÚ")
lista8
# Out:
# ['A', 'R', 'R', 'I', 'B', 'A', ' ', 'P', 'E', 'R', 'Ú']

# %%
lista8.index("R")
# Out:
# 1

# %%
frutas = ['manzana', 'banana', 'naranja', 'uva']

posicion = frutas.index("uva")
print(posicion)
# Out:
# 3

# %%
numeros = [10, 20, 30, 20, 40, 20]
posicion = numeros.index(20,2,5)
print(posicion)
# Out:
# 3

# %%
lista9=[12,49,86,123,160]
print(lista9)
x = lista9.pop(1)
print(x)
print(lista9)
# Out:
# [12, 49, 86, 123, 160]
# 49
# [12, 86, 123, 160]

# %%
frutas = ['manzana', 'banana', 'naranja']
print(frutas)
out = frutas.pop()
print(frutas)
# Out:
# ['manzana', 'banana', 'naranja']
# ['manzana', 'banana']

# %%
colores = ['rojo', 'verde', 'azul', 'amarillo']
print(colores)
out = colores.pop(1)
print(colores)
# Out:
# ['rojo', 'verde', 'azul', 'amarillo']
# ['rojo', 'azul', 'amarillo']

# %%
lista = [10, 20, 30, 40]

# %%
pila = []
print('-'*20)
print(pila)
pila.append(2026)
pila.append(2025)
pila.append(2024)
print(pila)
print('-'*20)
print(pila.pop())
print(pila.pop())
print(pila.pop())
print(pila)
print('-'*20)
# Out:
# --------------------
# []
# [2026, 2025, 2024]
# --------------------
# 2024
# 2025
# 2026
# []
# --------------------

# %%
tareas = ['lavar platos', 'barrer', 'cocinar']
while tareas:
    tareas_actual =  tareas.pop(0)
    print(f'procesando ... tarea realizada  {tareas_actual}  ')
# Out:
# procesando ... tarea realizada  lavar platos
# procesando ... tarea realizada  barrer
# procesando ... tarea realizada  cocinar

# %%
bool([])
# Out:
# False

# %%
bool([1])
# Out:
# True

# %%
frutas = ['manzana', 'banana', 'naranja']
frutas.remove('manzana')
print(frutas)
# Out:
# ['banana', 'naranja']

# %%
datos = ['A', 'B', 'C', 'B', 'D']
datos.remove('B')
print(datos)
# Out:
# ['A', 'C', 'B', 'D']

# %%
datos = ['A', 'B', 'C', 'B', 'D']
datos.pop(2)
print(datos)
# Out:
# ['A', 'B', 'B', 'D']

# %%
frutas = ['manzana', 'banana', 'naranja']
frutas.reverse()
print(frutas)
# Out:
# ['naranja', 'banana', 'manzana']

# %%
frutas = ['manzana', 'banana', 'naranja']
frutas.sort()
print(frutas)
# Out:
# ['banana', 'manzana', 'naranja']

# %%
dt_tupla = ()
print(dt_tupla)
print(type(dt_tupla))
#
dt_tupla = (12,34,45,33,56,123)
print(dt_tupla)
print(type(dt_tupla))
print("-"*20)
dt_tupla=(2)
print(dt_tupla)
# Out:
# ()
# <class 'tuple'>
# (12, 34, 45, 33, 56, 123)
# <class 'tuple'>
# 12
# 34
# 45
# 33
# 56
# 123
# --------------------
# 2

# %%
dt_tupla = (12,34,45,33,56,123)
print(id(dt_tupla))
dt_tupla = (322,100,200)
print(id(dt_tupla))
# Out:
# 124589450804384
# 124589450550080

# %%
import datetime
print(datetime)
# Out:
# <module 'datetime' from 'c:\\ProgramData\\anaconda3\\Lib\\datetime.py'>

# %%
dir(datetime)
# Out:
# ['MAXYEAR',
#  'MINYEAR',
#  'UTC',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'date',
#  'datetime',
#  'datetime_CAPI',
#  'time',
#  'timedelta',
#  'timezone',
#  'tzinfo']

# %%
datetime.MAXYEAR
# Out:
# 9999

# %%
datetime.MINYEAR
# Out:
# 1

# %%
ahora = datetime.datetime.now()
ahora
# Out:
# datetime.datetime(2026, 9, 7, 16, 21, 40, 672987)

# %%
d = datetime.date(2026,9,7)
d
# Out:
# datetime.date(2026, 9, 7)

# %%
datetime.date.today()
# Out:
# datetime.date(2026, 9, 7)

# %%
datetime.date.fromtimestamp()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 datetime.date.fromtimestamp()
#
# TypeError: date.fromtimestamp() takes exactly one argument (0 given)

# %%
datetime.date(1992,7,22).weekday()
# Out:
# 2

# %%
hoy = datetime.date.today()
print(hoy)
print(hoy.weekday())
print(hoy.isoformat())
# Out:
# 2026-09-07
# 0
# 2026-09-07

# %%
import datetime

fecha1 = datetime.date(1982,3,26)
fecha2 = datetime.date(2026,6,2)
print(fecha1)
print(fecha2)
print(type(fecha1))
print(type(fecha2))
tiempo = fecha2 - fecha1
print(tiempo)
print(type(tiempo))
# Out:
# 1982-03-26
# 2026-06-02
# <class 'datetime.date'>
# <class 'datetime.date'>
# 16139 days, 0:00:00
# <class 'datetime.timedelta'>

# %%
dir(fecha1)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__replace__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  'ctime',
#  'day',
#  'fromisocalendar',
#  'fromisoformat',
#  'fromordinal',
#  'fromtimestamp',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'min',
#  'month',
#  'replace',
#  'resolution',
#  'strftime',
#  'timetuple',
#  'today',
#  'toordinal',
#  'weekday',
#  'year']

# %%
fecha2.ctime()
# Out:
# 'Tue Jun  2 00:00:00 2026'

# %%
fecha2.day()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 fecha2.day()
#
# TypeError: 'int' object is not callable

# %%
fecha1.day
# Out:
# 26

# %%
fecha1.month
# Out:
# 3

# %%
fecha1.year
# Out:
# 1982

# %%
print(fecha1.year)
# Out:
# 1982

# %%
d1 = {}
d2 = dict()
d3 = {"A":(),"B":(1,2,3)}
print(d1)
print(d2)
print(d3)
"""  """
print(type(d1))
print(type(d2))
print(type(d3))
# Out:
# {}
# {}
# {'A': (), 'B': (1, 2, 3)}
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>

# %%
import math as m 
import random as rnd

# %%
d4 ={"one":rnd.randint(0,20),"two":rnd.randint(0,20),"three":rnd.randint(0,20)}

# almacenemos las propiedades de una particula
particula = {
    "nombre" : "Eletron",
    "masa_kg" : 9.109e-31,
    "carga_coulombs" : -1.60e-19,
    "es_estable" : True
}

# %%
coordenas = dict([("x",10.5),("y",-3.2),("z",0.0)])
print(coordenas)
# Out:
# {'x': 10.5, 'y': -3.2, 'z': 0.0}

# %%
registro = {}
registro["Cave"] = 18.5
registro["Zala"]=0.1
registro["Cabo"] = 0.0
registro
# Out:
# {'Cave': 18.5, 'Zala': 0.1, 'Cabo': 0.0}

# %%
# Out:
# {'PythonBasico': 4,
#  'MachineLearning': 2,
#  'DeepLearning': 3,
#  'PythonIntermedio': 6}

# %%
curso = ["PythonBasico", "MachineLearning", "DeepLearning", "PythonIntermedio"]
notas = [4, 2,3,6]
final = dict(zip(curso,notas))
final
# Out:
# {'PythonBasico': 4,
#  'MachineLearning': 2,
#  'DeepLearning': 3,
#  'PythonIntermedio': 6}

# %%
d5 = {"a":3,"b":2}
d6 = {"b":3.14 ,"c":4}
d7= d5 | d6
d7
# Out:
# {'a': 3, 'b': 3.14, 'c': 4}

# %%
"nombre"
