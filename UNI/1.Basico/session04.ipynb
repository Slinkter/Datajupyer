# %%
# !python --version
# Out:
# Python 3.14.7

# %%
x = range(0,100)
print(x[0])
print(x[10])
print(x[20])
print(x[30])
print(x[40])
print(x[50])
print(x[99])
print(len(x))
# Out:
# 0
# 10
# 20
# 30
# 40
# 50
# 99
# 100

# %%
tabla = int(input("ingresa el numero de la tabla multiplica"))
for temp in range(1,11):
    print(f" {temp} x {tabla} = : {temp*tabla}")
# Out:
#  1 x 2 = : 2
#  2 x 2 = : 4
#  3 x 2 = : 6
#  4 x 2 = : 8
#  5 x 2 = : 10
#  6 x 2 = : 12
#  7 x 2 = : 14
#  8 x 2 = : 16
#  9 x 2 = : 18
#  10 x 2 = : 20

# %%
x = range(12,24)
print(x)
print(x[1]) # 13
print(x[-1]) # 23
# Out:
# range(12, 24)
# 13
# 23

# %%
curso = "python"

for temp in curso:
    print(temp.capitalize())
# Out:
# P
# Y
# T
# H
# O
# N

# %%
curso
# Out:
# 'python'

# %%
curso_mat = "matematicas"
for temp in curso_mat:
    print(temp.upper(),end="-")
# Out:
# M-A-T-E-M-A-T-I-C-A-S-

# %%
curso_mat = "goal"
cadena = ""
for temp in curso_mat:
    cadena =  temp + cadena 

print(cadena)
# Out:
# laog

# %%
estrella = ""
nivel = 10

for  _ in range(0,nivel):
    estrella = estrella + "*"
    print(estrella)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********

# %%
nivel = 10

for  temp in range(nivel,0,-1):
    estrella =  "*" * temp
    print(estrella)
# Out:
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
texto_sucio = "Hola,  mundo! @123"
texto_limpio = ""


for tempStr in texto_sucio:
    if tempStr.isalpha():
        texto_limpio = texto_limpio + tempStr

print(texto_sucio)
print(texto_limpio)
# Out:
# Hola,  mundo! @123
# Holamundo

# %%
frase = "esta es la peor clase de mi vida sobre estructuras de repeticion"
vocales = "aeiou"
frase_ofuscada = ""

for letra in frase:
    if letra in vocales:
        frase_ofuscada = frase_ofuscada + "*"
    else:
        frase_ofuscada = frase_ofuscada + letra


print(frase)
print(frase_ofuscada)
# Out:
# esta es la peor clase de mi vida sobre estructuras de repeticion
# *st* *s l* p**r cl*s* d* m* v*d* s*br* *str*ct*r*s d* r*p*t*c**n

# %%
# while

# %%
contador_positivos = 0
suma_total = 0
print("INgresa un numero menor que cero para terminar")

input_num = float(input("Ingresar un numero"))

while(input_num >= 0):
    contador_positivos = contador_positivos +1
    suma_total = suma_total + input_num
    input_num = float(input("ingresa un numero"))

print(contador_positivos)
print(print(contador_positivos))
# Out:
# INgresa un numero menor que cero para terminar
# 0
# 0
# None

# %%
1
1

# %%
import random as rnd

contador = 0 

while true:
    for temp in range(0,1000):
        num_random = rnd.uniform(0,9)

    contador

# %%
import random as rnd
import time

contador = 0
inicio = time.time()

while contador <= 10**4:
    for _ in range(999):
        rnd.uniform(0,9)
    contador += 1

fin = time.time()

print(f"Operaciones totales: {contador * 999}")
print(f"Tiempo total: {fin - inicio:.4f} segundos")
# Out:
# Operaciones totales: 9990999
# Tiempo total: 5.5599 segundos

# %%
num = 1
while num <= 30:
    if (num % 3 != 0) and (num % 5 != 0):
        print(num)
    num += 1
# Out:
# 1
# 2
# 4
# 7
# 8
# 11
# 13
# 14
# 16
# 17
# 19
# 22
# 23
# 26
# 28
# 29
