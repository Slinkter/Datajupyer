# %% [markdown]
# ```python
# print("a")
# ```

# %%
print("a")
# Out:
# a

# %%
peso = 115 
estatura = 1.80
diametro = 49.9
gravedad = 9.81

# %%
type(gravedad)
# Out:
# float

# %%
type(peso)
# Out:
# int

# %%
import math as m
#help(m)

# %%
dir(m)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
radianes = m.radians(45)
rpta = m.tan(radianes)
print(rpta)
# Out:
# 0.9999999999999999

# %%
rpta = m.tan(45*m.pi/180)
print(rpta)
# Out:
# 0.9999999999999999

# %%
import random as rnd
dir(rnd)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
x = rnd.randint(11, 20)
print(x)
# Out:
# 11

# %%
help(rnd.randbytes)
# Out:
# Help on method randbytes in module random:
#
# randbytes(n) method of random.Random instance
#     Generate n random bytes.

# %%
y = rnd.random() * 100
print(y)
# Out:
# 5.206461944352581

# %%
s1 = "PIT620 : Python Basico"
s2 = 'Segunda Sesion (21/05/2026)'
s3 = """ Este es el peor curso de mi existencia. """

# %%
s4 = s1+" "+s2
s4
# Out:
# 'PIT620 : Python Basico Segunda Sesion (21/05/2026)'

# %%
s5 = 20*s1
s5
# Out:
# 'PIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python BasicoPIT620 : Python Basico'

# %%
s6 = s2 * 26
s6
# Out:
# 'Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)Segunda Sesion (21/05/2026)'

# %%
type(s6)
# Out:
# str

# %%
s2
# Out:
# 'Segunda Sesion (21/05/2026)'

# %%
print(s2[0])
print(s2[1])
print(s2[2])
print(s2[3])
print(s2[4])
print(s2[5])
print(s2[6])
# Out:
# S
# e
# g
# u
# n
# d
# a

# %%
s3
# Out:
# ' Este es el peor curso de mi existencia. '

# %%
s3[:5+1]
# Out:
# ' Este '

# %%
s3[-3]
# Out:
# 'a'

# %%
s3[-4:]
# Out:
# 'ia. '

# %%
s3[-4:-1]
# Out:
# 'ia.'

# %%
s3[-12:-1]
# Out:
# 'existencia.'

# %%
nombre = "jaime perez"

# %%
nombre[-25:]
# Out:
# 'jaime perez'

# %%
dir(nombre)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
nombre.upper()
# Out:
# 'JAIME PEREZ'

# %%
print(nombre.__doc__)
# Out:
# str(object='') -> str
# str(bytes_or_buffer[, encoding[, errors]]) -> str
#
# Create a new string object from the given object. If encoding or
# errors is specified, then the object must expose a data buffer
# that will be decoded using the given encoding and error handler.
# Otherwise, returns the result of object.__str__() (if defined)
# or repr(object).
# encoding defaults to sys.getdefaultencoding().
# errors defaults to 'strict'.

# %%
print(nombre.count("e"))
# Out:
# 3

# %%
"python".count("w")
# Out:
# 0

# %%
"teclado".count("a")
# Out:
# 1

# %%
"ministerio de cultura".count("u")
# Out:
# 2

# %%
"python".isalnum()
# Out:
# True

# %%
"python@".isalnum()
# Out:
# False

# %%
"2026".isalnum()
# Out:
# True

# %%
"2026-01-01".isalnum()
# Out:
# False

# %%
"nombre:jaime".isalnum()
# Out:
# False

# %%
"python".replace("o", "0")
# Out:
# 'pyth0n'

# %%
b1 = True
b2 = False

# %%
b3 = 12.0001<11
b3
# Out:
# False

# %%
b4 = 13 <= 18
b4
# Out:
# True

# %%
b5 = 3.50 > (2.7)**(-3.14159)
b5
# Out:
# True

# %%
b6 = 123.30 >= 3.14159**(2.71) 
b6
# Out:
# True

# %%
b7 = 12 == 11.9999999999999999
b7
# Out:
# True
